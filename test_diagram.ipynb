# %%
import datajoint as dj
from dotenv import load_dotenv
load_dotenv()
from emu24.settings import *
from emu24.helper import connect
connect()
from emu24.schema import ProbeConfig, Probes, MacroContacts, MicroContacts
# Out:
# /scratch/tahaismail424/miniforge3/envs/stitch_env/lib/python3.11/site-packages/datajoint/plugin.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2025-08-13 15:47:53,767][INFO]: DataJoint 0.14.4 connected to stitch-lead@localhost:3306
# Using settings for the development environment...
# Preparing datajoint connection settings...
# Connecting...
# Preparing datajoint connection settings...
# Connecting...

# %%
dj.Diagram(ProbeConfig).draw()
# Out:
# 2025-08-13 15:48:22,479 - DEBUG - STREAM b'IHDR' 16 13
# 2025-08-13 15:48:22,480 - DEBUG - STREAM b'bKGD' 41 6
# 2025-08-13 15:48:22,481 - DEBUG - b'bKGD' 41 6 (unknown)
# 2025-08-13 15:48:22,482 - DEBUG - STREAM b'IDAT' 59 2220
# 2025-08-13 15:48:22,502 - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-08-13 15:48:22,505 - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-08-13 15:48:22,516 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2025-08-13 15:48:22,518 - DEBUG - findfont: score(FontEntry(fname='/scratch/tahaismail424/miniforge3/envs/stitch_env/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# ...
